# %% [markdown]
# # Insertion at the end

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None
        
class LinkedList:
    def __init__(self):
        self.head=None
        
    def insert_at_end(self,data):
        newnode=Node(data)
        if self.head is None:
            self.head=newnode
        else:
            current_node=self.head
            while current_node.next is not None:
                current_node=current_node.next
            current_node.next=newnode
    
    def print(self):
        current_node=self.head
        while current_node is not None:
            print(current_node.data,"--> ",end="")
            current_node=current_node.next

# %%
L=LinkedList()
L.insert_at_end(10)
L.insert_at_end(11)
L.insert_at_end(12)
L.print()
# Out:
# 10 --> 11 --> 12 -->

# %% [markdown]
# # Insertion at the beginning

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None
        
class LinkedList:
    def __init__(self):
        self.head=None
        
    def insert_at_start(self,data):
        newnode=Node(data)
        if self.head is None:
            self.head=newnode
        else:
            newnode.next=self.head
            self.head=newnode
    
    def print(self):
        current_node=self.head
        while current_node is not None:
            print(current_node.data,"--> ",end="")
            current_node=current_node.next

# %%
L=LinkedList()
L.insert_at_start(10)
L.insert_at_start(11)
L.insert_at_start(12)
L.print()
# Out:
# 12 --> 11 --> 10 -->

# %% [markdown]
# # Insertion at the middle

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None
        
class LinkedList:
    def __init__(self):
        self.head=None
        
    def length(self):
        count=0
        current_node=self.head
        while current_node is not None:
            count+=1
            current_node=current_node.next
        return count
        
    def insert_at_start(self,data):
        newnode=Node(data)
        if self.head is None:
            self.head=newnode
        else:
            newnode.next=self.head
            self.head=newnode
            
    def insert_at_end(self,data):
        newnode=Node(data)
        if self.head is None:
            self.head=newnode
        else:
            current_node=self.head
            while current_node.next is not None:
                current_node=current_node.next
            current_node.next=newnode
    
    def insert_at_middle(self,data,pos):
        if pos<0 or pos>self.length():
            raise Exception("Invaild position")
        else:
            if pos==0:
                self.insert_at_start(data)
            elif pos==self.length():
                self.insert_at_end(data)
            else:
                newnode=Node(data)
                count=0
                current_node=self.head
                while current_node is not None:
                    if count==pos-1:
                        newnode.next=current_node.next
                        current_node.next=newnode
                        break
                    count+=1
                    current_node=current_node.next  
    
    def print(self):
        current_node=self.head
        while current_node is not None:
            print(current_node.data,"--> ",end="")
            current_node=current_node.next

# %%
L=LinkedList()
L.insert_at_end(10)
L.insert_at_start(11)
L.insert_at_end(12)
L.insert_at_end(13)
L.insert_at_start(14)
L.print()
print("\n")
L.insert_at_middle(15,3)
L.print()
print("\n")
L.insert_at_middle(16,5)
L.print()
print("\n")
# Out:
# 14 --> 11 --> 10 --> 12 --> 13 -->
#
# 14 --> 11 --> 10 --> 15 --> 12 --> 13 -->
#
# 14 --> 11 --> 10 --> 15 --> 12 --> 16 --> 13 -->

# %% [markdown]
# # Deletion at beginning

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None
        
class LinkedList:
    def __init__(self):
        self.head=None
        
    def length(self):
        count=0
        current_node=self.head
        while current_node is not None:
            count+=1
            current_node=current_node.next
        return count
        
    def insert_at_start(self,data):
        newnode=Node(data)
        if self.head is None:
            self.head=newnode
        else:
            newnode.next=self.head
            self.head=newnode
            
    def insert_at_end(self,data):
        newnode=Node(data)
        if self.head is None:
            self.head=newnode
        else:
            current_node=self.head
            while current_node.next is not None:
                current_node=current_node.next
            current_node.next=newnode
    
    def insert_at_middle(self,data,pos):
        if pos<0 or pos>self.length():
            raise Exception("Invaild position")
        else:
            if pos==0:
                self.insert_at_start(data)
            elif pos==self.length():
                self.insert_at_end(data)
            else:
                newnode=Node(data)
                count=0
                current_node=self.head
                while current_node is not None:
                    if count==pos-1:
                        newnode.next=current_node.next
                        current_node.next=newnode
                        break
                    count+=1
                    current_node=current_node.next
    
    def delete_at_start(self):
        self.head=self.head.next
    
    def print(self):
        current_node=self.head
        while current_node is not None:
            print(current_node.data,"--> ",end="")
            current_node=current_node.next

# %%
L=LinkedList()
L.insert_at_end(10)
L.insert_at_start(11)
L.insert_at_end(12)
L.insert_at_end(13)
L.insert_at_start(14)
L.print()
print("\n")
L.delete_at_start()
L.print()
# Out:
# 14 --> 11 --> 10 --> 12 --> 13 -->
#
# 11 --> 10 --> 12 --> 13 -->

# %% [markdown]
# # Deletion at end

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None
        
class LinkedList:
    def __init__(self):
        self.head=None
        
    def length(self):
        count=0
        current_node=self.head
        while current_node is not None:
            count+=1
            current_node=current_node.next
        return count
        
    def insert_at_start(self,data):
        newnode=Node(data)
        if self.head is None:
            self.head=newnode
        else:
            newnode.next=self.head
            self.head=newnode
            
    def insert_at_end(self,data):
        newnode=Node(data)
        if self.head is None:
            self.head=newnode
        else:
            current_node=self.head
            while current_node.next is not None:
                current_node=current_node.next
            current_node.next=newnode
    
    def insert_at_middle(self,data,pos):
        if pos<0 or pos>self.length():
            raise Exception("Invaild position")
        else:
            if pos==0:
                self.insert_at_start(data)
            elif pos==self.length():
                self.insert_at_end(data)
            else:
                newnode=Node(data)
                count=0
                current_node=self.head
                while current_node is not None:
                    if count==pos-1:
                        newnode.next=current_node.next
                        current_node.next=newnode
                        break
                    count+=1
                    current_node=current_node.next
    
    def delete_at_end(self):
        current_node=self.head
        while current_node.next is not None:
            temp=current_node
            current_node=current_node.next
        temp.next=None
    
    def print(self):
        current_node=self.head
        while current_node is not None:
            print(current_node.data,"--> ",end="")
            current_node=current_node.next

# %%
L=LinkedList()
L.insert_at_end(10)
L.insert_at_start(11)
L.insert_at_end(12)
L.insert_at_end(13)
L.insert_at_start(14)
L.print()
print("\n")
L.delete_at_end()
L.print()
print("\n")
# Out:
# 14 --> 11 --> 10 --> 12 --> 13 -->
#
# 14 --> 11 --> 10 --> 12 -->

# %% [markdown]
# # Deletion at the given index

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None
        
class LinkedList:
    def __init__(self):
        self.head=None
        
    def length(self):
        count=0
        current_node=self.head
        while current_node is not None:
            count+=1
            current_node=current_node.next
        return count
        
    def insert_at_start(self,data):
        newnode=Node(data)
        if self.head is None:
            self.head=newnode
        else:
            newnode.next=self.head
            self.head=newnode
            
    def insert_at_end(self,data):
        newnode=Node(data)
        if self.head is None:
            self.head=newnode
        else:
            current_node=self.head
            while current_node.next is not None:
                current_node=current_node.next
            current_node.next=newnode
    
    def insert_at_middle(self,data,pos):
        if pos<0 or pos>self.length():
            raise Exception("Invaild position")
        else:
            if pos==0:
                self.insert_at_start(data)
            elif pos==self.length():
                self.insert_at_end(data)
            else:
                newnode=Node(data)
                count=0
                current_node=self.head
                while current_node is not None:
                    if count==pos-1:
                        newnode.next=current_node.next
                        current_node.next=newnode
                        break
                    count+=1
                    current_node=current_node.next
    
    def delete_at_start(self):
        self.head=self.head.next
    
    def delete_at_end(self):
        current_node=self.head
        while current_node.next is not None:
            temp=current_node
            current_node=current_node.next
        temp.next=None
        
    def delete_at_index(self,pos):
        if pos<0 or pos>=self.length():
            raise Exception("Invaild position")
        else:
            if pos==0:
                self.delete_at_start()
            elif pos==self.length()-1:
                self.delete_at_end()
            else:
                count=0
                current_node=self.head
                while current_node is not None:
                    if count==pos-1:
                        current_node.next=current_node.next.next
                        break
                    count+=1
                    current_node=current_node.next
    
    def print(self):
        current_node=self.head
        while current_node is not None:
            print(current_node.data,"--> ",end="")
            current_node=current_node.next

# %%
L=LinkedList()
L.insert_at_end(10)
L.insert_at_start(11)
L.insert_at_end(12)
L.insert_at_end(13)
L.insert_at_start(14)
L.insert_at_start(15)
L.insert_at_start(16)
L.print()
print("\n")
L.delete_at_index(3)
L.print()
print("\n")
# Out:
# 16 --> 15 --> 14 --> 11 --> 10 --> 12 --> 13 -->
#
# 16 --> 15 --> 14 --> 10 --> 12 --> 13 -->

# %% [markdown]
# # Search a element

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None
        
class LinkedList:
    def __init__(self):
        self.head=None
        
    def length(self):
        count=0
        current_node=self.head
        while current_node is not None:
            count+=1
            current_node=current_node.next
        return count
        
    def insert_at_start(self,data):
        newnode=Node(data)
        if self.head is None:
            self.head=newnode
        else:
            newnode.next=self.head
            self.head=newnode
            
    def insert_at_end(self,data):
        newnode=Node(data)
        if self.head is None:
            self.head=newnode
        else:
            current_node=self.head
            while current_node.next is not None:
                current_node=current_node.next
            current_node.next=newnode
    
    def insert_at_middle(self,data,pos):
        if pos<0 or pos>self.length():
            raise Exception("Invaild position")
        else:
            if pos==0:
                self.insert_at_start(data)
            elif pos==self.length():
                self.insert_at_end(data)
            else:
                newnode=Node(data)
                count=0
                current_node=self.head
                while current_node is not None:
                    if count==pos-1:
                        newnode.next=current_node.next
                        current_node.next=newnode
                        break
                    count+=1
                    current_node=current_node.next
    
    def delete_at_start(self):
        self.head=self.head.next
    
    def delete_at_end(self):
        current_node=self.head
        while current_node.next is not None:
            temp=current_node
            current_node=current_node.next
        temp.next=None
        
    def delete_at_index(self,pos):
        if pos<0 or pos>=self.length():
            raise Exception("Invaild position")
        else:
            if pos==0:
                self.delete_at_start()
            elif pos==self.length()-1:
                self.delete_at_end()
            else:
                count=0
                current_node=self.head
                while current_node is not None:
                    if count==pos-1:
                        current_node.next=current_node.next.next
                        break
                    count+=1
                    current_node=current_node.next
                    
    def search_element(self,data):
        current_node=self.head
        while current_node is not None:
            if current_node.data==data:
                return True
            current_node=current_node.next
        return False
    
    def print(self):
        current_node=self.head
        while current_node is not None:
            print(current_node.data,"--> ",end="")
            current_node=current_node.next

# %%
L=LinkedList()
L.insert_at_end(10)
L.insert_at_start(11)
L.insert_at_end(12)
L.insert_at_end(13)
L.insert_at_start(14)
L.insert_at_start(15)
L.insert_at_start(16)
L.insert_at_end(17)
L.insert_at_end(18)
L.insert_at_end(19)
L.insert_at_end(20)
print("All the inserted elements: ")
L.print()
print("\n\nInserted element at given index: ")
L.insert_at_middle(15,3)
L.print()
print("\n\nDelete the starting element: ")
L.delete_at_start()
L.print()
print("\n\nDelete the last element: ")
L.delete_at_end()
L.print()
print("\n\nDelete the element at the given index: ")
L.delete_at_index(6)
L.print()
print("\n\nSearching an element: ")
ele=L.search_element(17)
if ele==True:
    print("Element found")
else:
    print("Element not found")
# Out:
# All the inserted elements:
# 16 --> 15 --> 14 --> 11 --> 10 --> 12 --> 13 --> 17 --> 18 --> 19 --> 20 -->
#
# Inserted element at given index:
# 16 --> 15 --> 14 --> 15 --> 11 --> 10 --> 12 --> 13 --> 17 --> 18 --> 19 --> 20 -->
#
# Delete the starting element:
# 15 --> 14 --> 15 --> 11 --> 10 --> 12 --> 13 --> 17 --> 18 --> 19 --> 20 -->
#
# Delete the last element:
# 15 --> 14 --> 15 --> 11 --> 10 --> 12 --> 13 --> 17 --> 18 --> 19 -->
#
# Delete the element at the given index:
# 15 --> 14 --> 15 --> 11 --> 10 --> 12 --> 17 --> 18 --> 19 -->
#
# Searching an element:
# Element found
